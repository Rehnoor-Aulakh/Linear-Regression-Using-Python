# %%
# %%time
# %matplotlib inline


import matplotlib.pyplot as plt
# Out:
# CPU times: user 411 µs, sys: 0 ns, total: 411 µs
# Wall time: 417 µs

# %%
import pandas as pd
df= pd.read_csv("chirps.csv")

# %%
df
# Out:
#             X          Y
# 0   20.000000  88.599998
# 1   16.000000  71.599998
# 2   19.799999  93.300003
# 3   18.400000  84.300003
# 4   17.100000  80.599998
# 5   15.500000  75.199997
# 6   14.700000  69.699997
# 7   17.100000  82.000000
# 8   15.400000  69.400002
# 9   16.200001  83.300003
# 10  15.000000  79.599998
# 11  17.200001  82.599998
# 12  16.000000  80.599998
# 13  17.000000  83.500000
# 14  14.400000  76.300003

# %%
import numpy as np
x = df.X.values
y = df.Y.values
x= np.reshape(x, (x.shape[0],1))
y = np.reshape(y, (y.shape[0],1))

# %%
from linear_model import LinearModel


model = LinearModel(1)
losses = model.train(
    x,y, 200, 0.0001
)
# Out:
# Iter: 0, Loss: 4474.7173
# Iter: 20, Loss: 1437.4261
# Iter: 40, Loss: 466.2450
# Iter: 60, Loss: 155.7075
# Iter: 80, Loss: 56.4123
# Iter: 100, Loss: 24.6623
# Iter: 120, Loss: 14.5101
# Iter: 140, Loss: 11.2638
# Iter: 160, Loss: 10.2257
# Iter: 180, Loss: 9.8937

# %%
plt.plot(losses)

# %%
y_preds= model.forward_pass(x)

# %%
plt.plot(y_preds, y, 'r.')

# %%
print(model.W, model.b)
# Out:
# [[4.8472696]] -1.252341132482842
